# %% [markdown]
# ### W6A1
# ### Nhập vào một dòng gồm các số nguyên. Hãy loại bỏ phần tử trùng nhưng giữnguyên thứ tự xuất hiện đầu tiên, rồi in ra list kết quả.Yêu cầu in ra đúng dạng list Python, ví dụ [1, 2, 3]

# %%
a=list(map(int,input().split()))
chuoi=set(a)
print(list(chuoi))
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# ### W6A2
# ### Nhập một dòng số nguyên. In ra list tổng tích lũy (phần tử i là tổng từ đầu tới vị trí i), giữ nguyên thứ tự

# %%
a=list(map(int,input().split()))
sum=0
tong=[]
for i in a:
    sum += int(i)
    tong.append(sum)
print(tong)
# Out:
# [10, 5, 15]

# %% [markdown]
# ### W6A3
# ### Nhập một tuple số nguyên (một dòng) và số nguyên k (dòng kế). In ra tuple sau khi xoay trái k vị trí. (Giữ nguyên thứ tự tương đối sau xoay; không sắp xếp.)

# %%
tup=tuple(map(int,input().split()))
k=int(input())
ket_qua=tup[k:]+tup[:k]
print(ket_qua)
# Out:
# (0, 1, 1)

# %% [markdown]
# ### W6A4
# ### Nhập một dòng gồm các cặp key:value cách nhau bởi dấu cách. Tạo dictionary ánh xạ mỗi key -> list các value theo thứ tự xuất hiện. Nếu key lặp lại, thêm vào list của key đó

# %%
chuoi=input()
chuoi1=chuoi.split()
ket_qua={}
for i in chuoi1:
    key,value=i.split(":")
    if key not in ket_qua:
        ket_qua[key]=[]
    ket_qua[key].append(value)   
print(ket_qua)
# Out:
# {'a': ['1', '3'], 'b': ['2']}

# %% [markdown]
# ### W6A5
# ### Nhập một list số nguyên, In ra dictionary {'positives': ..., 'negatives': ..., 'zeros':...} (đếm số >0, <0, =0)

# %%
day=list(map(int,input().split()))
lon_hon_0=0
nho_hon_0=0
bang_0=0
for i in day:
    if i>0:
        lon_hon_0 +=1
    if i<0:
        nho_hon_0 +=1
    if i==0:
        bang_0 +=1
dict={
    "postives":lon_hon_0,
    "negatives":nho_hon_0,
    "zezos":bang_0

}  
print(dict)
# Out:
# {'postives': 0, 'negatives': 3, 'zezos': 0}

# %% [markdown]
# ### W6A6
# ### Viết chương trình nhập vào một danh sách các số nguyên, sau đó in ra tổng các số trong list đó.

# %%
a=list(map(int,input().split()))
tong=0
for i in a:
    tong += int(i)
print(tong)
# Out:
# -6

# %% [markdown]
# ### W6A7
# ### Viết chương trình nhập vào một tuple, in ra phần tử đầu, phần tử cuối, và tuple đảo ngược

# %%
tup=tuple(input().split())
a=tup[::-1]
print(f"{tup[0]} {tup[-1]} {a}")
# Out:
# 10 20 ('20', '10')

# %% [markdown]
# ### W6A8
# ### Viết chương trình nhập vào một list các chuỗi, sau đó đếm số lần xuất hiện của từng chuỗi và lưu vào dictionary

# %%
a=list(input().split())
dem={}
for i in a:
    x=a.count(i)
    dem[i]=x
print(dem)
# Out:
# {'apple': 2, 'banana': 1}

# %% [markdown]
# ### W6A9
# ### Viết chương trình nhập vào hai dictionary. Sau đó gộp lại thành mộtdictionary mới trong đó nếu một key xuất hiện trong cả hai dict, giá trị sẽ được cộng lại, nếu chỉ có trong một dict thì giữ nguyên. In ra dictionary mới theo thứ tự từ điển tăng dần của key

# %%
def input_dict(dict):
    dict_input=input.split()
    d={}
    if dict_input:
        phan_tus= dict_input.split(",")
        for phan_tu in phan_tus:
            key,value=phan_tu.split(":")
            d[key.split()]=int(value.split())
    return d
dict1=input_dict()
dict2=input_dict()
new_dict1=dict1.copy()
for key in dict2:
    if key in new_dict1:
        new_dict1[key]+= dict2[key]
    else:
        new_dict1[key] = dict2[key] 
keys=list(new_dict1.key())
for i in range(len(keys)):
    for j in range(0,len(keys)-i-1):
        if keys[j]>keys[j+1]:
            keys[j],keys[j+1]=keys[j+1],key[j]
dict={}
for key in keys:
    dict[key]=new_dict1[key]
print(dict)

# %% [markdown]
# ### W6A10
# ### Viết chương trình nhập vào một danh sách các số nguyên, và số nguyên dương k. In ra list gồm các cặp số khác nhau có tổng bằng k. Mỗi cặp là một tuple, hai số trong tuple có thể giống nhau, thứ tự xuất hiện trong danh sách của số thứ nhất nhỏ hơn thứ tự của số thứ hai. Các tuple trong list được sắp xếp theo thứ tự tăng dần của phần tử đầu tiên trong tuple

# %%
day=list(map(int,input().split()))
k=int(input())
lst=[]
for i in range(len(day)):
    for j in range(i+1,len(day)):
        if day[i]+day[j]==k:
            lst.append((day[i],day[j]))
sap_xep_lst=[]
for x in lst:
    if x not in sap_xep_lst:
        sap_xep_lst.append(x)
for i in range(len(sap_xep_lst)):
    for j in range(0,len(sap_xep_lst)-i-1):
        if sap_xep_lst[j][0]>sap_xep_lst[j+1][0]:
            sap_xep_lst[j],sap_xep_lst[j+1]=sap_xep_lst[j+1],sap_xep_lst[j]
print(sap_xep_lst)
# Out:
# [(1, 5), (2, 4)]

# %% [markdown]
# ### W6A11
# ### Nhập vào một tuple chứa các số nguyên. Hãy tạo ra hai tuple mới: một chứa tất cả các số chẵn và một chứa tất cả các số lẻ từ tuple ban đầu, giữ nguyên thứ tự tương đối. In ra hai tuple này trên hai dòng riêng biệt

# %%
tup=tuple(map(int,input().split()))
so_chan=[]
so_le=[]
for i in range(len(tup)):
    if tup[i]%2==0:
        so_chan.append(tup[i])
    else:
        so_le.append(tup[i])
print(tuple(so_chan))
print(tuple(so_le))
# Out:
# (2, 4)
# (1, 3, 5)

# %% [markdown]
# ### W6A12
# ### Nhập vào một list các số nguyên. Hãy tìm số xuất hiện nhiều lần nhất trong list. Nếu có nhiều số cùng có số lần xuất hiện nhiều nhất, hãy in ra số nhỏ nhất trong số đó.

# %%
lst=list(map(int,input().split()))
max_count=0
max_value=lst[0]
lst.sort()
for i in lst:
    x=lst.count(i)
    if x>max_count:
        max_count=x
        max_value=i
print(max_value)
# Out:
# 2

# %% [markdown]
# ### W6A13
# ### Nhập vào một dictionary có value là duy nhất (không trùng nhau). Hãy tạo một dictionary mới bằng cách đảo ngược key và value của dictionary ban đầu. In ra dictionary mới.

# %%
keys=input().split()
values=input().split()
dict={}
dict2={}
for i in range(len(keys)):
    key=keys[i]
    value=values[i]
    dict[key]=value
    dict2[value]=key
print(dict2)
# Out:
# {'an': 'ten', '15': 'tuoi', '10a1': 'lop'}

# %% [markdown]
# ### W6A14
# ### Nhập vào hai dòng, mỗi dòng là một danh sách các số nguyên. Hãy tìm các phần tử chung (giao) của hai danh sách này và in ra một list mới chứa các phần tử chung đó, không trùng lặp.

# %%
lst1=list(map(int,input().split()))
lst2=list(map(int,input().split()))
lst=[]
for i in lst1:
    if i in lst2:
        lst.append(i)
a=set(lst) 
print(list(a))
# Out:
# [2, 4, 6]

# %% [markdown]
# ### W6A15
# ### Nhập vào một dictionary có key là chuỗi và value là số nguyên, và một số nguyên k ở dòng tiếp theo. Hãy tạo một dictionary mới chỉ chứa các cặp key-value từ dictionary ban đầu mà có value lớn hơn k. In ra dictionary mới.

# %%
def tao_dict(d, k):
    res = {}
    for key, value in d.items():
        if value > k:
            res[key] = value
    return res
keys=list(map(str,input().split()))
values=list(map(int,input().split()))
k=int(input())
d = dict(zip(keys, values))
print(tao_dict(d,k))
