# %% [markdown]
# ### W3A1
# ### Viết một chương trình nhập vào một số nguyên n và in ra các chữ số đảo ngược nhau.

# %%
n=input()
if n.startswith("-"):
    so_dao_nguoc="-"+ n[:0:-1]
else:
    so_dao_nguoc=n[::-1]
print(so_dao_nguoc)
# Out:
# 54321

# %% [markdown]
# ### W3A2
# ## Hoán đổi hai số không sd biến tạm thời
# ## Sử dụng phép toán XOR bitwise để hoán đổi giá trị của hai biến

# %%
a,b=map(int,input().split())
a=a^b
b=a^b
a=a^b
print(a,b)

# %%
a,b=map(int,input().split())
a,b=b,a
print(a,b)

# %% [markdown]
# ### W3A3
# ### Kiểm tra xem một số có phải là lũy thừa của 2 hay không
# ### Sử dụng các toán tử bitwise để xác định xem một số có phải là lũy thừa của 2 hay không.
# ### Gợi ý: Đối với lũy thừa của 2, n & (n-1) == 0

# %%
n=int(input())
if n>0 and n&(n-1)==0:
    print('la luy thua cua 2')
else:
    print("khong la luy thua ua 2")

# %% [markdown]
# ### W3A4
# ### viêt chương trình chia một số m cho n, kết quả thu được làm tròn xuống

# %%
import math
m,n=map(int,input().split())
ket_qua=math.floor(m/n)
print(ket_qua)

# %% [markdown]
# ### W3A5
# ### viêt chương trình chia một số m cho n, kết quả thu được làm tròn lên

# %%
import math
m,n=map(int,input().split())
ket_qua=math.ceil(m/n)
print(ket_qua)

# %% [markdown]
# ### W3A6
# ### [Even and Odd]
# ### Nhập vào một số nguyên dương x, bạn hãy kiểm tra xem x là số chẵn hay lẻ. Nếu x là số chẵn, in ra "Even". Nếu x là số lẻ, in ra "Odd".

# %%
x=int(input())
if x>0:
    if x%2==0:
        print("Even")
    else:
        print("Odd")
else:
    print("nhap lai")

# %% [markdown]
# ### W3A7
# ### [Check negative numbers]
# ### Nhập vào hai số nguyên a, b. Nếu cả hai số a, b đều âm thì in ra "Yes", ngược lại in ra "No".

# %%
a,b=map(int,input().split())
if a<0 and b<0:
    print("Yes")
else:
    print("No")

# %% [markdown]
# ### W3A8
# ### [Longer string]
# ### Nhập vào hai chuỗi a, b gồm các chữ cái thường. In ra "True" nếu chuỗi a dài hơn chuỗi b. Ngược lại in ra "False"

# %%
a=str(input())
b=str(input())
if len(a)>len(b):
    print("True")
else:
    print("False")

# %% [markdown]
# ### W3A9
# ### [Triangle]
# ### Nhập vào 3 số nguyên dương a, b, c. Kiểm tra xem a, b, c có cấu thành độ dài cạnh của 1 tam giác được không.Nếu a, b, c cấu tạo thành được một tam giác, in ra "Yes". Ngược lại in ra "No".

# %%
a=int(input())
b=int(input())
c=int(input())
if a>0 and b>0 and c>0:
    if a+b>c and a+c>b and b+c>a:
        print("Yes")
    else:
        print("No")
else:
    print("nhap lai ")

# %% [markdown]
# ### W3A10
# ### Nhập vào 4 số nguyên. In ra màn hình số nguyên lớn nhất trong 4 số.

# %%
a=int(input())
b=int(input())
c=int(input())
d=int(input())
lon_nhat=max(a,b,c,d)
print(lon_nhat)

# %% [markdown]
# ### W3A11
# ### [Phân loại tam giác]
# ### Nhập vào 3 số nguyên dương a,b,c là độ dài 3 cạnh của một tam giác. Kiểm tra 3 số đã nhập có tạo thành một tam giác hợplệ hay không. Nếu không in ra "Không phải tam giác". Nếu có, phân loại tam giác đó là "Tam giác đều", "Tam giác cân", hay"Tam giác thường".

# %%
a = float(input())
b = float(input())
c = float(input())
if (a + b > c) and (a + c > b) and (b + c > a):
    if a == b == c:
        print("Tam giác đều")
    elif a == b or a == c or b == c:
        if a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
            print("Tam giác vuông cân")
        else:
            print("Tam giác cân")
    elif a**2 + b**2 == c**2 or a**2 + c**2 == b**2 or b**2 + c**2 == a**2:
        print("Tam giác vuông")
    else:
        print("Tam giác thường")
else:
    print("Khong la ba canh cua mot tam giac")

# %% [markdown]
# ### W3A12
# ### [Kiểm tra năm nhuận]
# ### Nhập vào một số nguyên dương n là số năm, kiểm tra xem năm đó có phải là năm nhuận hay không. Năm nhuận là năm chia hết cho 4 nhưng không chia hết cho 100, hoặc chia hết cho 400. Nếu là năm nhuận in ra "Yes", nếu không in ra "No"

# %%
nam=int(input())
if nam%400==0 or (nam%4==0 and nam%100!=0):
    print("Yes")
else:
    print("No")

# %% [markdown]
# ### W3A13
# ### [Tính tiền điện]
# ### Nhập vào số kWh điện tiêu thụ. Tính tiền điện theo các bậc sau:
# ### - 0-50 kWh: 1500đ/kWh
# ### - 51-100 kWh: 2000đ/kWh
# ### - 100 kWh: 3000đ/kWh

# %%
n=int(input())
if n <= 50:
    print(n*1500)
elif 50<n<=100:
    print(50*1500+(n-50)*2000)
else:
    print(50*1500+50*2000+(n-100)*3000)

# %% [markdown]
# ### W3A14
# ### [Giải phương trình bậc nhất]
# ### Nhập vào hai số thực a và b của phương trình ax + b = 0. Tìm và in ra nghiệm của phương trình, kết quả làm tròn đến số thập phân thứ 2. In ra "Vô nghiệm" hoặc "Vô số nghiệm" trong trường hợp tương ứng.

# %%
a=float(input())
b=float(input())
if a==0:
    print(" vo nghiem ")
elif a==0 and b==0:
    print("vo so nghiem")
else:
    x=-b/a
    print(round(x,2))

# %% [markdown]
# ### W3A15
# ### [Xếp loại học lực]
# ### Nhập vào điểm trung bình của một học sinh và in ra học lực của học sinh đó. Xếp loại học lực theo quy tắc:
# ### - >= 8.0: Giỏi
# ### - >= 6.5: Khá
# ### - >= 5.0: Trung bình
# ### - < 5.0: Yếu

# %%
n=float(input())
if 8.0 <=n<=10:
    print("gioi")
elif 6.5 <= n <8.0:
    print("kha")
elif 5.0 <= n < 6.5:
    print("trung binh") 
elif 0<= n <5.0:
    print("yeu")
else:
    print("khong hop le ")

# %% [markdown]
# ### W3A16
# ### [Rounding]
# ### Nhập vào một số thực: in ra kết quả làm tròn lên ,tròn xuống, làm tròn tới số nguyên gần nhất (không được sử dụng hàmsẵn có của pyton). Các kết quả cách nhau một dấu cách

# %%
x = float(input(""))
if x >= 0:
    tron_xuong = int(x)
else:
    if x == int(x):
        tron_xuong = int(x)
    else:
        tron_xuong = int(x) - 1
if x == int(x):
    tron_len = int(x)
else:
    if x >= 0:
        tron_len = int(x) + 1
    else:
        tron_len = int(x)
if x >= 0:
    gan_nhat = int(x + 0.5)
else:
    gan_nhat = int(x - 0.5)

print(f"{tron_len} {tron_xuong} {gan_nhat}")

# %% [markdown]
# ### W3A17
# ### Cấp số nhân
# ### Cho 4 số a, b, c, d. Hãy kiểm tra xem 4 số này có thể theo thứ tự tạo thành 1 cấp số nhân với công bội nguyên theo đúng thứ tự a, b, c, d hay không?
# ### Gợi ý : Tìm công bội (b / a) nếu b chia hết cho a, sau đó lấy b nhân công bội và so sánh vs c, c nhân công bội và so sánh vs d.

# %%
a, b, c, d = map(int, input().split())
la_cap_so_nhan = False
if a != 0:
    if b % a == 0: 
        q = b // a
        if c == b * q and d == c * q:
            la_cap_so_nhan = True
else:
    if b == 0 and c == 0 and d == 0:
        la_cap_so_nhan = True
if la_cap_so_nhan:
    print("YES")
else:
    print("NO")
